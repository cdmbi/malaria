# %%
import pandas as pd
import numpy as np

# %%
# %time

df = pd.read_csv("results_10000.csv")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 10 µs

# %%
df_data = df.ix[:,1:]

# %%
df
# Out:
#                                                   smiles  \
# 0                     Cc1nc(N)nc(N)c1OCCCOc1cccc(Cl)c1Cl
# 1            CC1(C)NC(N)=NC(=N)N1OCCCOc1c(Cl)cc(Cl)cc1Cl
# 2             CC1(C)NC(N)=NC(=N)N1OCCOc1cccc(c1)C(F)(F)F
# 3                     Cc1ccc(CON2C(=N)N=C(N)NC2(C)C)cc1C
# 4                  CCC(C)(C)n1c(C)cc2c1ccc1nc(N)nc(N)c21
# 5                       CC1(C)NC(N)=NC(=N)N1OCCSc1ccccc1
# 6                     COc1ccccc1CCCON1C(=N)N=C(N)NC1(C)C
# 7                CCCOc1ccc(OCCCON2C(=N)N=C(N)NC2(C)C)cc1
# 8                  CCc1cccc(OCCCON2C(=N)N=C(N)NC2(C)C)c1
# 9             CC1(C)NC(N)=NC(=N)N1OCCCc1cccc(c1)C(F)(F)F
# 10                  CC1(C)N=C(N)N=C(N)N1c1ccc(Cl)c(Cl)c1
# 11                    Cc1ccccc1OCCCON1C(=N)N=C(N)NC1(C)C
# 12        CC1(C)NC(N)=NC(=N)N1OCCCCOc1ccc(Cl)cc1C1CCCCC1
# 13        CC1(C)NC(N)=NC(=N)N1OCCCCCCOc1ccc(Cl)c2ccccc12
# 14                    CCC1N=C(N)N=C(N)N1OCc1cccc2ccccc12
# ...

# %%
import numpy as np

grouped = df.groupby(['smiles'], as_index=False)

# %%
grouped.agg([np.max])
# Out:
#                                                    CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C@@]3(OC(C)=O)[C@H]2[C@H](OC(=O)c2ccccc2)[C@]2(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C)OCCO  \
#                                                                                                                                                                                                                    amax
# smiles
# Brc1cc(Br)c(OCCN2C(=O)c3ccccc3C2=O)c(CNCCCNc2cc...                                           0.089474
# Brc1cc(Br)c2NCCC(NCCCNC3CCNc4c(Br)cc(Br)cc34)c2c1                                            0.070513
# Brc1cc(Br)c2NCCC(NCCCNc3nc4ncccc4[nH]3)c2c1                                                  0.087912
# Brc1cc(Br)cc(CNC(CCNc2cc(=O)c3ccccc3[nH]2)CNCCc...                                           0.098361
# Brc1cc(Br)cc(CNC(CCNc2cc(=O)c3ccccc3[nH]2)CNCc2...                                           0.089947
# ...

# %%
 df.groupby(['smiles']).mean()
# Out:
#                                                     CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C@@]3(OC(C)=O)[C@H]2[C@H](OC(=O)c2ccccc2)[C@]2(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C)OCCO  \
# smiles
# Brc1cc(Br)c(OCCN2C(=O)c3ccccc3C2=O)c(CNCCCNc2cc...                                           0.089474
# Brc1cc(Br)c2NCCC(NCCCNC3CCNc4c(Br)cc(Br)cc34)c2c1                                            0.070513
# Brc1cc(Br)c2NCCC(NCCCNc3nc4ncccc4[nH]3)c2c1                                                  0.087912
# Brc1cc(Br)cc(CNC(CCNc2cc(=O)c3ccccc3[nH]2)CNCCc...                                           0.098361
# Brc1cc(Br)cc(CNC(CCNc2cc(=O)c3ccccc3[nH]2)CNCc2...                                           0.089947
# Brc1cc(Br)cc(CNC(CCNc2cc(=O)c3ccccc3[nH]2)CNCc2...                                           0.087432
# Brc1cc(Br)cc(CN[C@H]2CCC[C@@H]2CNc2cc(=O)c3cccc...                                           0.079096
# ...

# %%
df_data.cummax
# Out:
# <bound method DataFrame.max of        CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C@@]3(OC(C)=O)[C@H]2[C@H](OC(=O)c2ccccc2)[C@]2(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C)OCCO  \
# 0                                               0.086957
# 1                                               0.067073
# 2                                               0.070175
# 3                                               0.075000
# 4                                               0.061350
# 5                                               0.101266
# 6                                               0.079755
# 7                                               0.079755
# 8                                               0.089820
# 9                                               0.070588
# 10                                              0.072848
# 11                                              0.091463
# 12                                              0.084270
# ...

# %%
df_data
# Out:
#        CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C@@]3(OC(C)=O)[C@H]2[C@H](OC(=O)c2ccccc2)[C@]2(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C)OCCO  \
# 0                                               0.086957
# 1                                               0.067073
# 2                                               0.070175
# 3                                               0.075000
# 4                                               0.061350
# 5                                               0.101266
# 6                                               0.079755
# 7                                               0.079755
# 8                                               0.089820
# 9                                               0.070588
# 10                                              0.072848
# 11                                              0.091463
# 12                                              0.084270
# ...

# %%
df_data.mean(axis = 1)
# Out:
# 0        0.080314
# 1        0.075290
# 2        0.087329
# 3        0.084467
# 4        0.066096
# 5        0.087173
# 6        0.086986
# 7        0.087563
# 8        0.093291
# 9        0.092566
# 10       0.068042
# 11       0.086990
# 12       0.092889
# 13       0.095709
# 14       0.095377
# 15       0.086250
# 16       0.078172
# 17       0.072128
# 18       0.082980
# 19       0.090759
# 20       0.079075
# 21       0.084813
# 22       0.074793
# 23       0.067338
# 24       0.089823
# 25       0.063249
# 26       0.087444
# 27       0.079592
# 28       0.077503
# 29       0.086698
#            ...
# 13373    0.095657
# 13374    0.119312
# 13375    0.118587
# 13376    0.097590
# 13377    0.127035
# 13378    0.105058
# 13379    0.104431
# 13380    0.084141
# 13381    0.098122
# 13382    0.097864
# 13383    0.127438
# 13384    0.093428
# 13385    0.107960
# 13386    0.128419
# 13387    0.108628
# 13388    0.116258
# 13389    0.111542
# 13390    0.098225
# 13391    0.122722
# ...

# %%
df_data.mean()
# Out:
# CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C@@]3(OC(C)=O)[C@H]2[C@H](OC(=O)c2ccccc2)[C@]2(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C)OCCO                                                            0.110105
# CC(=O)O[C@@H]1C2=C(C)[C@H]3OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4C\C=C\CO[C@@H]3[C@@](O)([C@@H](OC(=O)c3ccccc3)[C@@H]3[C@@]4(CO[C@@H]4C[C@H](O)[C@@]3(C)C1=O)OC(C)=O)C2(C)C)C=C(C)C                                                0.094368
# CC(=O)O[C@@H]1C2=C(C)C(C[C@@](O)([C@@H](OCc3ccccc3)C3[C@@]4(CO[C@@H]4C[C@H](OCOCCO)[C@@]3(C)C1=O)OC(C)=O)C2(C)C)OC(=O)[C@H](O)[C@@H](NC(=O)OC(C)(C)C)c1ccco1                                                                    0.107631
# NCCOCCOCCOCCOCCOCCOCC(=O)Nc1cc(C[C@H](NS(=O)(=O)c2cccc(c2)C(F)(F)F)C(O)=O)ccc1OCCCc1ccc2CCCNc2n1                                                                                                                                0.117064
# ...

# %%
# %time
data = pd.read_csv("ChEMBL_21_MWTlt900_standardized.csv")
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 15 µs

# %%
data
# Out:
#                                                     smiles     MWT  \
# 0        CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C...  899.99
# 1        CC(=O)O[C@@H]1C2=C(C)[C@H]3OC(=O)[C@H](O)[C@@H...  899.99
# 2        CC(=O)O[C@@H]1C2=C(C)C(C[C@@](O)([C@@H](OCc3cc...  899.98
# 3        NCCOCCOCCOCCOCCOCCOCC(=O)Nc1cc(C[C@H](NS(=O)(=...  899.98
# 4        COc1ccc(C[C@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H]...  899.95
# 5        COc1ccccc1C[C@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@...  899.95
# 6        COc1cccc(C[C@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H...  899.95
# 7        CC(C)N(CC[C@H](c1ccccc1)c1cc(CCNC(=O)CCCCCNC(=...  899.95
# 8        CC(=O)N[C@@H](CC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(...  899.94
# 9        COc1ccc(OC)c(c1)C(=O)O[C@H]1[C@@H]2[C@@]3(CO[C...  899.94
# 10       CCCCOC(=O)N[C@H]([C@@H](O)C(=O)O[C@H]1C[C@@]2(...  899.94
# 11       CC(C)C[C@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)...  899.92
# 12       CCCCCCCCCCCCCC(=O)OC(COCCCCCCCCCCCC)COP(O)(=O)...  855.94
# ...

# %%
from pandas import DataFrame, read_csv

import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib
# %matplotlib inline

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib verion ' + matplotlib.__version__)
# Out:
# Python version 2.7.11 |Anaconda 2.5.0 (64-bit)| (default, Dec  6 2015, 18:08:32)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# Pandas version 0.17.1
# Matplotlib verion 1.5.1

# %%
# the Initla st of baby names and birth rates
names = ['Bob', 'Jessica', 'Mary', 'John', 'Mel']
births = [968, 155, 77, 587, 973]

# %%
zip?

# %%
BabyDataSet = list(zip(names, births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 587), ('Mel', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet,
                 columns = ['Names', 'Births'])

# %%
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     587
# 4      Mel     973

# %%
df.dtypes
# Out:
# Names     object
# Births     int64
# dtype: object

# %%
df.Births.dtype
# Out:
# dtype('int64')

# %%
Sorted = df.sort_values(['Births'], ascending = False)
Sorted.head(1)
# Out:
#   Names  Births
# 4   Mel     973

# %%
Sorted.head(1)
# Out:
#   Names  Births
# 4   Mel     973

# %%
# Method 2:
df['Births'].max()
# Out:
# 973

# %%
df_data.max()
# Out:
# CC(=O)O[C@H]1[C@H](O)[C@]2(C)[C@H](C[C@H]3OC[C@@]3(OC(C)=O)[C@H]2[C@H](OC(=O)c2ccccc2)[C@]2(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C)OCCO                                                            0.204819
# CC(=O)O[C@@H]1C2=C(C)[C@H]3OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4C\C=C\CO[C@@H]3[C@@](O)([C@@H](OC(=O)c3ccccc3)[C@@H]3[C@@]4(CO[C@@H]4C[C@H](O)[C@@]3(C)C1=O)OC(C)=O)C2(C)C)C=C(C)C                                                0.185185
# CC(=O)O[C@@H]1C2=C(C)C(C[C@@](O)([C@@H](OCc3ccccc3)C3[C@@]4(CO[C@@H]4C[C@H](OCOCCO)[C@@]3(C)C1=O)OC(C)=O)C2(C)C)OC(=O)[C@H](O)[C@@H](NC(=O)OC(C)(C)C)c1ccco1                                                                    0.240741
# NCCOCCOCCOCCOCCOCCOCC(=O)Nc1cc(C[C@H](NS(=O)(=O)c2cccc(c2)C(F)(F)F)C(O)=O)ccc1OCCCc1ccc2CCCNc2n1                                                                                                                                0.252941
# ...

# %%
# !ls
# Out:
# analysis.ipynb			     target_fps_240000.Rds
# ChEMBL_21_MWTlt900_standardized.csv  target_fps_250000.Rds
# chemical_similarity_search.R	     target_fps_260000.Rds
# GAMO_PFdata_200115.csv		     target_fps_270000.Rds
# query_fp_GAMPO.Rds		     target_fps_280000.Rds
# README.md			     target_fps_290000.Rds
# results_100000.csv		     target_fps_300000.Rds
# results_10000.csv		     target_fps_30000.Rds
# results_10000.csv.tar.gz	     target_fps_310000.Rds
# results_10000.Rds		     target_fps_320000.Rds
# results_110000.csv		     target_fps_330000.Rds
# results_120000.csv		     target_fps_340000.Rds
# results_130000.csv		     target_fps_350000.Rds
# results_140000.csv		     target_fps_360000.Rds
# results_20000.csv		     target_fps_370000.Rds
# results_30000.csv		     target_fps_380000.Rds
# results_40000.csv		     target_fps_390000.Rds
# results_50000.csv		     target_fps_400000.Rds
# results_60000.csv		     target_fps_40000.Rds
# results_70000.csv		     target_fps_410000.Rds
# ...

# %%
df_data_2 = pd.read_csv('results_20000.csv')

# %%
df_data_2.max()
# Out:
# smiles                                                                                                                                                                                           c1ncn(n1)-c1ccccc1
# C[C@@H]1O[C@@H](O[C@@H]2[C@@H](O)[C@@H](O)CO[C@H]2O[C@H]2CC[C@@]3(C)[C@@H](CC[C@]4(C)[C@@H]3CC=C3[C@@H]5CC(C)(C)CC[C@@]5(CC[C@@]43C)C(=O)N3CCOCC3)[C@]2(C)CO)[C@H](O)[C@H](O)[C@H]1O                       0.181287
# CC[C@H](C)[C@H](NC(=O)[C@H]1CCCCN1C)C(=O)N(CSCCO)[C@H](C[C@@H](OC(C)=O)c1nc(cs1)C(=O)N[C@H](C[C@H](C)C(O)=O)Cc1ccc(O)cc1)C(C)C                                                                             0.231638
# CC[C@H]1OC(=O)[C@H](C)C(=O)[C@H](C)[C@@H](O[C@@H]2O[C@H](C)C[C@@H]([C@H]2O)N(C)C)[C@](C)(C[C@@H](C)C2=NCCN3[C@H]([C@H]2C)[C@]1(C)OC3=O)OCC#Cc1ccc(cc1)-c1cccs1                                             0.202312
# ...

# %%
# !ls
# Out:
# analysis.ipynb			     target_fps_240000.Rds
# ChEMBL_21_MWTlt900_standardized.csv  target_fps_250000.Rds
# chemical_similarity_search.R	     target_fps_260000.Rds
# GAMO_PFdata_200115.csv		     target_fps_270000.Rds
# query_fp_GAMPO.Rds		     target_fps_280000.Rds
# README.md			     target_fps_290000.Rds
# results_100000.csv		     target_fps_300000.Rds
# results_10000.csv		     target_fps_30000.Rds
# results_10000.csv.tar.gz	     target_fps_310000.Rds
# results_10000.Rds		     target_fps_320000.Rds
# results_110000.csv		     target_fps_330000.Rds
# results_120000.csv		     target_fps_340000.Rds
# results_130000.csv		     target_fps_350000.Rds
# results_140000.csv		     target_fps_360000.Rds
# results_20000.csv		     target_fps_370000.Rds
# results_30000.csv		     target_fps_380000.Rds
# results_40000.csv		     target_fps_390000.Rds
# results_50000.csv		     target_fps_400000.Rds
# results_60000.csv		     target_fps_40000.Rds
# results_70000.csv		     target_fps_410000.Rds
# ...

# %%
df_data_3 = pd.read_csv('results_30000.csv')
df_data_3.max()
# Out:
# smiles                                                                                                                                                                                              c1ncn(n1)-c1ccccc1
# CC[C@H](C)[C@@H](NC(=O)OCc1ccccc1)C(=O)C[C@@H](Cc1ccccc1)[C@H](O)[C@H](Cc1ccccc1)NC(=O)[C@@H](NC(=O)OCc1ccccc1)[C@@H](C)CC                                                                                    0.275862
# CCC[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)N[C@@H](CC(C)C)[C@@H](O)CC(=O)N[C@@H](C)C(=O)N[C@@H](CC(C)C)[C@@H](O)CC(=O)OC                                                                             0.473214
# CCCC[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)N[C@@H](CC(C)C)[C@@H](O)CC(=O)N[C@@H](C)C(=O)N[C@@H](CC(C)C)[C@@H](O)CC(O)=O                                                                             0.464286
# ...

# %%
df_data_4 = pd.read_csv('results_40000.csv')
df_data_4.max()
# Out:
# smiles                                                                                                                                                                      c1ncn(n1)-c1ccccc1
# C[C@@H]1C[C@]2(SCC(N)=N2)C2(O)O[C@@H]3C[C@@]4(COC(=O)c5ccccc5)[C@@H](CC[C@@H]5[C@@H]4CC[C@]4(C)[C@H](CC[C@]54CO)C4=CC(=O)OC4)C[C@H]3O[C@@H]2O1                                        0.194805
# COc1ccc(cc1)C(C1C(CC(=Nc2c(C)noc12)c1ccccc1)c1ccccc1)C1C(CC(=Nc2c(C)noc12)c1ccccc1)c1ccccc1                                                                                           0.313725
# CN(C)CCOc1cccc(c1)C(=O)NC[C@H](Cc1ccc(OCCc2nc(oc2C)-c2ccccc2)cc1)Nc1ccccc1C(=O)c1ccccc1                                                                                               0.564286
# CCCCCOC(=O)N1CCN(CC1)C(=O)[C@H](CCC(=O)OC(C)(C)C)NC(=O)c1cc(NC(=O)N2CCC(CC2)OC)cc(n1)-c1ccccc1                                                                                        0.260274
# ...

# %%
df_data_5 = pd.read_csv('results_50000.csv')
df_data_5.max()
# Out:
# Unnamed: 0                                                                                                                                                             13403.000000
# Cc1ccc2cccc(OCc3c(Cl)ccc(c3Cl)S(=O)(=O)NC(C)(C)C(=O)N3CCN(CCCCCCN=C(N)N)CC3)c2n1                                                                                           0.260000
# Cc1ccc2cccc(OCc3c(Cl)ccc(c3Cl)S(=O)(=O)NC(C)(C)C(=O)N3CCN(CC3)C(=N)NCCCCCCN)c2n1                                                                                           0.243421
# COC(=O)CC[C@H](NC(=O)c1ccc(cc1)N(C)Cc1cnc2nc(\N=N\c3ccc(O)cc3)nc(\N=N\c3ccc(O)cc3)c2n1)C(=O)OC                                                                             0.443609
# CC1CC(C)(C)NC(CCOP(=O)(OC[C@H]2O[C@H](C[C@@H]2O)n2cc(F)c(=O)[nH]c2=O)N(C)CCOS(=O)(=O)c2ccc(C)cc2)O1                                                                        0.215190
# ...

# %%
df_data_6 = pd.read_csv('results_60000.csv')
df_data_6.max()
# Out:
# Unnamed: 0                                                                                                                                                             13403.000000
# Cc1ccc2cccc(OCc3c(Cl)ccc(c3Cl)S(=O)(=O)NC(C)(C)C(=O)N3CCN(CCCCCCN=C(N)N)CC3)c2n1                                                                                           0.260000
# Cc1ccc2cccc(OCc3c(Cl)ccc(c3Cl)S(=O)(=O)NC(C)(C)C(=O)N3CCN(CC3)C(=N)NCCCCCCN)c2n1                                                                                           0.243421
# COC(=O)CC[C@H](NC(=O)c1ccc(cc1)N(C)Cc1cnc2nc(\N=N\c3ccc(O)cc3)nc(\N=N\c3ccc(O)cc3)c2n1)C(=O)OC                                                                             0.443609
# CC1CC(C)(C)NC(CCOP(=O)(OC[C@H]2O[C@H](C[C@@H]2O)n2cc(F)c(=O)[nH]c2=O)N(C)CCOS(=O)(=O)c2ccc(C)cc2)O1                                                                        0.215190
# ...

# %%
df_data_7 = pd.read_csv('results_70000.csv')
df_data_7.max()
# Out:
# Unnamed: 0                                                                                                                   13403.000000
# Cc1ccc2cccc(OCc3c(Cl)ccc(c3Cl)S(=O)(=O)NC(C)(C)C(=O)NCCCNCc3ccc(F)cc3)c2n1                                                       0.236111
# COc1cc2c(Nc3cc(CC(=O)Nc4cccc(F)c4F)[nH]n3)ncnc2cc1OCCCN1CCC[C@@H]1COP(O)(O)=O                                                    0.364238
# O=C(Cn1c2ccccc2c2cc[n+]3nc(c(cc3c12)-c1cccc2ccccc12)-c1cccc2ccccc12)NCC#C                                                        0.231250
# Cc1nc(N)ccc1CNC(=O)C1C=CCn2n1c(=O)n(C(CSc1ccc(Cl)c(Cl)c1)C(=O)OC1CCCCC1)c2=O                                                     0.235669
# Cn1cnc(c1)S(=O)(=O)N(Cc1ccc(cc1)S(C)(=O)=O)C1Cc2cc(Br)ccc2N(Cc2cncn2C)C1=O                                                       0.218543
# CCCOc1ccc(-c2cc(on2)C(C(=O)OCCOCCO)n2cc3nc(nc3cn2)-c2cccc(F)c2F)c(c1)C(F)(F)F                                                    0.211640
# ...

# %%
df_data_8 = pd.read_csv('results_80000.csv')
df_data_8.max()
